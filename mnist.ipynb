# %%
from keras.datasets import mnist
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils
from keras.layers import Dense,Activation,Dropout
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.utils import validation
from sklearn import preprocessing

# %%
(X_train,Y_train),(X_test,Y_test)=mnist.load_data()
plt.imshow(X_train[1])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %%
for i in range(9):
  plt.subplot(330+i+1)
  plt.imshow(X_train[i],cmap=plt.get_cmap('gray'))
plt.show()

# %%
X_train=X_train.reshape(60000,784)#784 28x28
X_test=X_test.reshape(10000,784)
X_train=X_train.astype('float32')
X_test=X_test.astype('float32')
X_train/=255
X_test/=255
Y_train=np_utils.to_categorical(Y_train,10)
Y_test=np_utils.to_categorical(Y_test,10)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_test.shape
# Out:
# (10000, 784)

# %%
Y_train.shape
# Out:
# (60000, 10)

# %%
model=Sequential() 
model.add(Dense(512,activation='relu',input_shape=(784,))) 
model.add(Dropout(0.1))
model.add(Dense(512,activation='relu')) 
model.add(Dropout(0.1)) 
model.add(Dense(10,activation='softmax')) 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer=RMSprop(),metrics=['accuracy'])
history= model.fit(X_train, Y_train, batch_size=128, epochs=500, verbose=1, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/500
# 375/375 [==============================] - 9s 21ms/step - loss: 0.2596 - accuracy: 0.9185 - val_loss: 0.1342 - val_accuracy: 0.9592
# Epoch 2/500
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0998 - accuracy: 0.9696 - val_loss: 0.0937 - val_accuracy: 0.9722
# Epoch 3/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0666 - accuracy: 0.9801 - val_loss: 0.0978 - val_accuracy: 0.9737
# Epoch 4/500
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.0855 - val_accuracy: 0.9775
# Epoch 5/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0407 - accuracy: 0.9872 - val_loss: 0.1085 - val_accuracy: 0.9738
# Epoch 6/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0318 - accuracy: 0.9900 - val_loss: 0.1086 - val_accuracy: 0.9756
# Epoch 7/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.1067 - val_accuracy: 0.9788
# Epoch 8/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.1101 - val_accuracy: 0.9787
# Epoch 9/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0190 - accuracy: 0.9938 - val_loss: 0.1230 - val_accuracy: 0.9787
# Epoch 10/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0171 - accuracy: 0.9946 - val_loss: 0.1304 - val_accuracy: 0.9786
# Epoch 11/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.1263 - val_accuracy: 0.9787
# Epoch 12/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.1348 - val_accuracy: 0.9803
# Epoch 13/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0137 - accuracy: 0.9960 - val_loss: 0.1396 - val_accuracy: 0.9793
# Epoch 14/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0115 - accuracy: 0.9960 - val_loss: 0.1334 - val_accuracy: 0.9822
# Epoch 15/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.1578 - val_accuracy: 0.9782
# Epoch 16/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0097 - accuracy: 0.9969 - val_loss: 0.1425 - val_accuracy: 0.9817
# Epoch 17/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.1611 - val_accuracy: 0.9807
# Epoch 18/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1564 - val_accuracy: 0.9806
# Epoch 19/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0092 - accuracy: 0.9973 - val_loss: 0.1630 - val_accuracy: 0.9810
# Epoch 20/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0099 - accuracy: 0.9974 - val_loss: 0.1776 - val_accuracy: 0.9812
# Epoch 21/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0089 - accuracy: 0.9973 - val_loss: 0.1941 - val_accuracy: 0.9795
# Epoch 22/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0084 - accuracy: 0.9981 - val_loss: 0.1835 - val_accuracy: 0.9796
# Epoch 23/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.1973 - val_accuracy: 0.9808
# Epoch 24/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.1795 - val_accuracy: 0.9812
# Epoch 25/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.1983 - val_accuracy: 0.9816
# Epoch 26/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.2049 - val_accuracy: 0.9817
# Epoch 27/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 0.2172 - val_accuracy: 0.9787
# Epoch 28/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0068 - accuracy: 0.9984 - val_loss: 0.2308 - val_accuracy: 0.9790
# Epoch 29/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.2272 - val_accuracy: 0.9813
# Epoch 30/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.2357 - val_accuracy: 0.9803
# Epoch 31/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 0.2326 - val_accuracy: 0.9795
# Epoch 32/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.2366 - val_accuracy: 0.9809
# Epoch 33/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 0.2088 - val_accuracy: 0.9823
# Epoch 34/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0069 - accuracy: 0.9983 - val_loss: 0.2297 - val_accuracy: 0.9811
# Epoch 35/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0072 - accuracy: 0.9983 - val_loss: 0.2271 - val_accuracy: 0.9804
# Epoch 36/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 0.2490 - val_accuracy: 0.9811
# Epoch 37/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.2534 - val_accuracy: 0.9818
# Epoch 38/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.2439 - val_accuracy: 0.9826
# Epoch 39/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.2861 - val_accuracy: 0.9803
# Epoch 40/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.2574 - val_accuracy: 0.9812
# Epoch 41/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.2586 - val_accuracy: 0.9828
# Epoch 42/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0065 - accuracy: 0.9986 - val_loss: 0.2899 - val_accuracy: 0.9793
# Epoch 43/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.2495 - val_accuracy: 0.9819
# Epoch 44/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0055 - accuracy: 0.9989 - val_loss: 0.2697 - val_accuracy: 0.9818
# Epoch 45/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0067 - accuracy: 0.9988 - val_loss: 0.2590 - val_accuracy: 0.9803
# Epoch 46/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.2549 - val_accuracy: 0.9815
# Epoch 47/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.2720 - val_accuracy: 0.9817
# Epoch 48/500
# 375/375 [==============================] - 7s 20ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.2989 - val_accuracy: 0.9808
# Epoch 49/500
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.2661 - val_accuracy: 0.9827
# Epoch 50/500
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 0.2790 - val_accuracy: 0.9808
# Epoch 51/500
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0060 - accuracy: 0.9988 - val_loss: 0.2515 - val_accuracy: 0.9824
# Epoch 52/500
# 375/375 [==============================] - 8s 20ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.2753 - val_accuracy: 0.9823
# Epoch 53/500
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0043 - accuracy: 0.9990 - val_loss: 0.2606 - val_accuracy: 0.9818
# Epoch 54/500
# 375/375 [==============================] - 8s 21ms/step - loss: 0.0046 - accuracy: 0.9990 - val_loss: 0.3021 - val_accuracy: 0.9825

# %%
Score=model.evaluate(X_test,Y_test,verbose=0)
print('Test Loss', Score[0])
print('Test Accuracy', Score[1])
# Out:
# Test Loss 0.23600320518016815
# Test Accuracy 0.9830999970436096

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('mnist.ipynb')
# Out:
# Mounted at /content/drive
# --2022-04-30 03:13:26--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2022-04-30 03:13:26 (23.5 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/mnist.ipynb to pdf
# [NbConvertApp] Support files will be in mnist_files/
# [NbConvertApp] Making directory ./mnist_files
# [NbConvertApp] Making directory ./mnist_files
# [NbConvertApp] Making directory ./mnist_files
# [NbConvertApp] Writing 40621 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 67969 bytes to /content/drive/My Drive/mnist.pdf
# 'File ready to be Downloaded and Saved to Drive'
