# %%
from keras.datasets import fashion_mnist
import matplotlib.pyplot as plt
import numpy as np
from keras.utils import np_utils
from keras.layers import Dense,Activation,Dropout
from keras.models import Sequential
from tensorflow.keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import scale
from sklearn.preprocessing import StandardScaler
from sklearn.utils import validation
from sklearn import preprocessing

# %%
(X_train,Y_train),(X_test,Y_test)=fashion_mnist.load_data()
plt.imshow(X_train[1])
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
for i in range(9):
  plt.subplot(330+i+1)
  plt.imshow(X_train[i],cmap=plt.get_cmap('gray'))
plt.show()

# %%
for i in range(9):
  plt.subplot(330+i+1)
  plt.imshow(X_train[i])
plt.show()

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %%
Y_train.shape
# Out:
# (60000,)

# %%
X_train=X_train.reshape(60000,784)#784 28x28
X_test=X_test.reshape(10000,784)
X_train=X_train.astype('float32')
X_test=X_test.astype('float32')
X_train/=255
X_test/=255
Y_train=np_utils.to_categorical(Y_train,10)
Y_test=np_utils.to_categorical(Y_test,10)

# %%
model=Sequential() 
model.add(Dense(512,activation='relu',input_shape=(784,))) 
model.add(Dropout(0.1))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1)) 
model.add(Dense(10,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               401920
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 669,706
# Trainable params: 669,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer=RMSprop(), metrics=['accuracy'])

# %%
history= model.fit(X_train, Y_train, batch_size=128, epochs=500, verbose=1, validation_split=0.2, callbacks=[EarlyStopping(monitor='val_loss', patience=50)])
# Out:
# Epoch 1/500
# 375/375 [==============================] - 8s 19ms/step - loss: 0.5827 - accuracy: 0.7864 - val_loss: 0.4212 - val_accuracy: 0.8478
# Epoch 2/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.4014 - accuracy: 0.8532 - val_loss: 0.3785 - val_accuracy: 0.8633
# Epoch 3/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.3605 - accuracy: 0.8676 - val_loss: 0.3862 - val_accuracy: 0.8620
# Epoch 4/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.3334 - accuracy: 0.8776 - val_loss: 0.3501 - val_accuracy: 0.8804
# Epoch 5/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.3164 - accuracy: 0.8825 - val_loss: 0.3558 - val_accuracy: 0.8817
# Epoch 6/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.3036 - accuracy: 0.8884 - val_loss: 0.3427 - val_accuracy: 0.8812
# Epoch 7/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2936 - accuracy: 0.8921 - val_loss: 0.3596 - val_accuracy: 0.8804
# Epoch 8/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2860 - accuracy: 0.8939 - val_loss: 0.3427 - val_accuracy: 0.8892
# Epoch 9/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2783 - accuracy: 0.8969 - val_loss: 0.3498 - val_accuracy: 0.8857
# Epoch 10/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2714 - accuracy: 0.9010 - val_loss: 0.3484 - val_accuracy: 0.8880
# Epoch 11/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2658 - accuracy: 0.9027 - val_loss: 0.3757 - val_accuracy: 0.8842
# Epoch 12/500
# 375/375 [==============================] - 7s 19ms/step - loss: 0.2608 - accuracy: 0.9047 - val_loss: 0.4147 - val_accuracy: 0.8769
# Epoch 13/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2570 - accuracy: 0.9057 - val_loss: 0.3490 - val_accuracy: 0.8903
# Epoch 14/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2505 - accuracy: 0.9075 - val_loss: 0.4027 - val_accuracy: 0.8792
# Epoch 15/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2444 - accuracy: 0.9116 - val_loss: 0.3771 - val_accuracy: 0.8939
# Epoch 16/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2407 - accuracy: 0.9108 - val_loss: 0.4332 - val_accuracy: 0.8840
# Epoch 17/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2409 - accuracy: 0.9135 - val_loss: 0.3992 - val_accuracy: 0.8935
# Epoch 18/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2358 - accuracy: 0.9138 - val_loss: 0.3923 - val_accuracy: 0.8943
# Epoch 19/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2323 - accuracy: 0.9164 - val_loss: 0.4539 - val_accuracy: 0.8897
# Epoch 20/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2263 - accuracy: 0.9178 - val_loss: 0.4155 - val_accuracy: 0.8958
# Epoch 21/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2280 - accuracy: 0.9167 - val_loss: 0.4316 - val_accuracy: 0.8932
# Epoch 22/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2206 - accuracy: 0.9197 - val_loss: 0.4389 - val_accuracy: 0.8903
# Epoch 23/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2180 - accuracy: 0.9209 - val_loss: 0.4824 - val_accuracy: 0.8848
# Epoch 24/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2151 - accuracy: 0.9219 - val_loss: 0.4440 - val_accuracy: 0.8952
# Epoch 25/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2141 - accuracy: 0.9226 - val_loss: 0.5129 - val_accuracy: 0.8908
# Epoch 26/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2123 - accuracy: 0.9233 - val_loss: 0.5110 - val_accuracy: 0.8946
# Epoch 27/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2093 - accuracy: 0.9245 - val_loss: 0.5112 - val_accuracy: 0.8903
# Epoch 28/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2086 - accuracy: 0.9264 - val_loss: 0.5018 - val_accuracy: 0.8937
# Epoch 29/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2047 - accuracy: 0.9252 - val_loss: 0.4761 - val_accuracy: 0.8915
# Epoch 30/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2046 - accuracy: 0.9268 - val_loss: 0.5597 - val_accuracy: 0.8870
# Epoch 31/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.2025 - accuracy: 0.9275 - val_loss: 0.5427 - val_accuracy: 0.8856
# Epoch 32/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2029 - accuracy: 0.9281 - val_loss: 0.4935 - val_accuracy: 0.8938
# Epoch 33/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.2033 - accuracy: 0.9281 - val_loss: 0.5366 - val_accuracy: 0.8895
# Epoch 34/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.1958 - accuracy: 0.9300 - val_loss: 0.5525 - val_accuracy: 0.8910
# Epoch 35/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1958 - accuracy: 0.9310 - val_loss: 0.5794 - val_accuracy: 0.8906
# Epoch 36/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1964 - accuracy: 0.9301 - val_loss: 0.5811 - val_accuracy: 0.8950
# Epoch 37/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1944 - accuracy: 0.9315 - val_loss: 0.6165 - val_accuracy: 0.8896
# Epoch 38/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1906 - accuracy: 0.9320 - val_loss: 0.6021 - val_accuracy: 0.8924
# Epoch 39/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1931 - accuracy: 0.9337 - val_loss: 0.5645 - val_accuracy: 0.8919
# Epoch 40/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1866 - accuracy: 0.9345 - val_loss: 0.6298 - val_accuracy: 0.8898
# Epoch 41/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1845 - accuracy: 0.9341 - val_loss: 0.5790 - val_accuracy: 0.8970
# Epoch 42/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1810 - accuracy: 0.9365 - val_loss: 0.6657 - val_accuracy: 0.8856
# Epoch 43/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1827 - accuracy: 0.9359 - val_loss: 0.6596 - val_accuracy: 0.8899
# Epoch 44/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1832 - accuracy: 0.9361 - val_loss: 0.6059 - val_accuracy: 0.8953
# Epoch 45/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1828 - accuracy: 0.9364 - val_loss: 0.6930 - val_accuracy: 0.8894
# Epoch 46/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1848 - accuracy: 0.9358 - val_loss: 0.7024 - val_accuracy: 0.8896
# Epoch 47/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1782 - accuracy: 0.9386 - val_loss: 0.6704 - val_accuracy: 0.8965
# Epoch 48/500
# 375/375 [==============================] - 7s 17ms/step - loss: 0.1742 - accuracy: 0.9398 - val_loss: 0.7655 - val_accuracy: 0.8847
# Epoch 49/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1782 - accuracy: 0.9373 - val_loss: 0.6702 - val_accuracy: 0.8887
# Epoch 50/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1749 - accuracy: 0.9398 - val_loss: 0.6547 - val_accuracy: 0.8957
# Epoch 51/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1736 - accuracy: 0.9401 - val_loss: 0.8160 - val_accuracy: 0.8817
# Epoch 52/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1736 - accuracy: 0.9402 - val_loss: 0.7473 - val_accuracy: 0.8861
# Epoch 53/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1738 - accuracy: 0.9410 - val_loss: 0.7111 - val_accuracy: 0.8886
# Epoch 54/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1699 - accuracy: 0.9410 - val_loss: 0.7736 - val_accuracy: 0.8949
# Epoch 55/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1727 - accuracy: 0.9413 - val_loss: 0.7736 - val_accuracy: 0.8929
# Epoch 56/500
# 375/375 [==============================] - 7s 18ms/step - loss: 0.1653 - accuracy: 0.9429 - val_loss: 0.7768 - val_accuracy: 0.8900

# %%
Score=model.evaluate(X_test,Y_test,verbose=0)
print('Test Loss', Score[0])
print('Test Accuracy', Score[1])
# Out:
# Test Loss 0.8651280403137207
# Test Accuracy 0.8838000297546387

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train','Validation'])
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !wget -nc https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
from colab_pdf import colab_pdf
colab_pdf('fashion_mnist.ipynb')
# Out:
# Mounted at /content/drive
# --2022-04-30 03:04:11--  https://raw.githubusercontent.com/brpy/colab-pdf/master/colab_pdf.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1864 (1.8K) [text/plain]
# Saving to: ‘colab_pdf.py’
#
# colab_pdf.py        100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2022-04-30 03:04:11 (46.3 MB/s) - ‘colab_pdf.py’ saved [1864/1864]
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Extracting templates from packages: 100%
# [NbConvertApp] Converting notebook /content/drive/MyDrive/Colab Notebooks/fashion_mnist.ipynb to pdf
# [NbConvertApp] Support files will be in fashion_mnist_files/
# [NbConvertApp] Making directory ./fashion_mnist_files
# [NbConvertApp] Making directory ./fashion_mnist_files
# [NbConvertApp] Making directory ./fashion_mnist_files
# [NbConvertApp] Making directory ./fashion_mnist_files
# [NbConvertApp] Writing 43731 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', './notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', './notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 121402 bytes to /content/drive/My Drive/fashion_mnist.pdf
# 'File ready to be Downloaded and Saved to Drive'
